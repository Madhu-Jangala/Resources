# %% [markdown]
# # 📘 Flotorch Email Ticket Router Demo
#
# This notebook demonstrates how to automate email-based ticket routing using Flotorch Agents and custom tools for Gmail.
#
# ## 🧭 Workflow Overview
#
# 1. **Fetch unread emails** from your inbox
# 2. **The agent** (configured in Flotorch Console) analyzes each email:
#    - Detects intent (bug, feature, issue, etc.)
#    - Determines routing team & priority
#    - Summarizes the issue clearly
# 3. **Automatically routes** the task to the correct team lead
# 4. **Sends acknowledgment** to the sender confirming receipt
#
# ## 💡 Goal
#
# Streamline internal task management from **"email → assignment"** in one autonomous flow.

# %% [markdown]
# # 📋 PRE-RUN CHECKLIST
#
# Before you run this notebook, complete these setup steps:
#
# ## 1️⃣ Create a Flotorch Agent in Console
#
# - **Agent name**: `support-ticket-inbox-router` (or match `AGENT_NAME` variable)
# - **System Prompt**:
#       You are the Support Ticket Inbox Router.
#
#       Workflow:
#
#       1) Call fetch_mail_tool() - which returns a list of unread emails in the form:
#          [{ "id": "...", "sender": "...", "subject": "...", "body": "..." }, ...]
#
#       2) For each email returned:
#          a) Analyze subject+body and produce a structured JSON with keys:
#             - intent: one of ["bug","feature","task","issue","query"]
#             - title: short developer-friendly title
#             - summary: 1-3 sentence summary with reproduction steps if provided
#             - routing_team: one of ["ui","python_backend","views_backend","devops","qa","technical"]
#             - priority: one of ["P0 - Critical","P1 - High","P2 - Medium","P3 - Low","P4 - Info"]
#             - recommended_sla: e.g. "Immediate (<30m)", "1 hour", "4 hours", "24 hours"
#             - ack_message: short text to send to sender
#             - notify_message: short text to send to lead
#
#          b) Call route_task_tool(routing_team, title, summary, priority)
#             - expect result: {"lead_name","lead_email","status"}
#
#          c) Call send_ack_tool(sender, ack_message, ack_subject) to acknowledge sender.
#
#       3) After processing all emails, return a summary JSON list of processed items with their tool-call statuses.
#
#       Important: Only call the tools above. Do not send emails yourself — use send_ack_tool and route_task_tool to send messages. Be deterministic and concise.
#       **STRICTLY CALL ALL TOOLS** for correct working flow.
#
# - **Goal**:
#       To automatically manage and route internal task or issue requests received via email.
#       When executed, this agent:
#       1. Fetches new emails from a configured inbox using the fetch_mail tool.
#       2. Analyzes each email’s subject and body to identify its intent (bug, feature, issue, or task), summarize the content, and determine the responsible team.
#       3. Uses reasoning to decide the priority and urgency of each item.
#       4. Invokes tools to route the task to the correct team lead (via email or future task system integration).
#       5. Sends an acknowledgment reply to the original sender confirming the action taken.
#       The agent ensures that communication between the sender and the responsible team is automated and consistent.
#
# - **Model Settings**: add llm model
# - **Save/Deploy**: Save and publish the agent
#
# ## 2️⃣ Create and Store Your Flotorch Credentials
#
# In the notebook **Configuration** cell, set:
#
# ```python
# FLOTORCH_API_KEY = "sk_..."
# FLOTORCH_BASE_URL = "https://<your-gateway>.flotorch.cloud"
# ```
#
# ## 3️⃣ Prepare Gmail (App Password + IMAP)
#
# ### Steps:
#
# 1. **Sign in** to your Gmail account
# 2. **Enable 2-Step Verification** (if not already enabled)
# 3. **Create an App Password**:
#    - Go to **Google Account → Security → App passwords**
#    - Select **App**: Mail, **Device**: Other, name (e.g., "Notebook")
#    - Copy the 16-character app password
# 4. **Enable IMAP** in Gmail settings:
#    - Gmail → Settings → See all settings → Forwarding and POP/IMAP → **Enable IMAP**
#
# ### In the notebook Configuration cell, set:
#
# ```python
# GMAIL_EMAIL = "your_email@gmail.com"
# GMAIL_APP_PASSWORD = "16-char-app-password"
# ```
#
# ## 4️⃣ Customize Team Leads
#
# In the notebook `TEAMS` dict, set correct `lead_emails` for your organization.
#
# ## refer last cell for sample examples do a test mail with that sample

# %%
# %pip install flotorch[adk]
# Out:
# Requirement already satisfied: flotorch[adk] in c:\git_files\resources\resources\venv\lib\site-packages (3.2.1)
# Requirement already satisfied: httpx>=0.24 in c:\git_files\resources\resources\venv\lib\site-packages (from flotorch[adk]) (0.28.1)
# Requirement already satisfied: pydantic>=1.10 in c:\git_files\resources\resources\venv\lib\site-packages (from flotorch[adk]) (2.12.5)
# Requirement already satisfied: google-adk>=1.5.0 in c:\git_files\resources\resources\venv\lib\site-packages (from flotorch[adk]) (1.28.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (4.13.0)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.6.9)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (8.3.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (0.135.3)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.193.0)
# Requirement already satisfied: google-auth>=2.47.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk>=1.5.0->flotorch[adk]) (2.49.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.132.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.144.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.37.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (3.41.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.35.0)
# Requirement already satisfied: google-cloud-dataplex<3.0.0,>=1.7.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.18.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.36.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.27.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (3.64.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.38.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (3.10.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.64.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.70.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (0.21)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.26.0)
# Requirement already satisfied: opentelemetry-api<1.39.0,>=1.36.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.36.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (23.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.33.1)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (1.17.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (2.0.48)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (0.42.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]) (15.0.1)
# Requirement already satisfied: certifi in c:\git_files\resources\resources\venv\lib\site-packages (from httpx>=0.24->flotorch[adk]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\git_files\resources\resources\venv\lib\site-packages (from httpx>=0.24->flotorch[adk]) (1.0.9)
# Requirement already satisfied: idna in c:\git_files\resources\resources\venv\lib\site-packages (from httpx>=0.24->flotorch[adk]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\git_files\resources\resources\venv\lib\site-packages (from httpcore==1.*->httpx>=0.24->flotorch[adk]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\git_files\resources\resources\venv\lib\site-packages (from pydantic>=1.10->flotorch[adk]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\git_files\resources\resources\venv\lib\site-packages (from pydantic>=1.10->flotorch[adk]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\git_files\resources\resources\venv\lib\site-packages (from pydantic>=1.10->flotorch[adk]) (0.4.2)
# Requirement already satisfied: opentelemetry-instrumentation-httpx>=0.48b0 in c:\git_files\resources\resources\venv\lib\site-packages (from flotorch[adk]) (0.59b0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.34.0 in c:\git_files\resources\resources\venv\lib\site-packages (from flotorch[adk]) (1.38.0)
# Requirement already satisfied: cryptography in c:\git_files\resources\resources\venv\lib\site-packages (from authlib<2.0.0,>=1.6.6->google-adk>=1.5.0->flotorch[adk]) (46.0.6)
# Requirement already satisfied: colorama in c:\git_files\resources\resources\venv\lib\site-packages (from click<9.0.0,>=8.1.8->google-adk>=1.5.0->flotorch[adk]) (0.4.6)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\git_files\resources\resources\venv\lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk>=1.5.0->flotorch[adk]) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]) (0.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\git_files\resources\resources\venv\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]) (2.30.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk>=1.5.0->flotorch[adk]) (0.4.2)
# Requirement already satisfied: pyopenssl>=20.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk>=1.5.0->flotorch[adk]) (26.0.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.27.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.17.0)
# Requirement already satisfied: docstring_parser<1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.19.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (3.15.0)
# Requirement already satisfied: google-cloud-iam in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (2.22.0)
# Requirement already satisfied: aiohttp in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (3.13.5)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk>=1.5.0->flotorch[adk]) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk>=1.5.0->flotorch[adk]) (2.8.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-bigquery-storage>=2.0.0->google-adk>=1.5.0->flotorch[adk]) (1.80.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk>=1.5.0->flotorch[adk]) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk>=1.5.0->flotorch[adk]) (1.8.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-pubsub<3.0.0,>=2.0.0->google-adk>=1.5.0->flotorch[adk]) (1.80.0)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]) (2.30.0)
# Requirement already satisfied: mmh3>=4.1.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]) (5.2.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\git_files\resources\resources\venv\lib\site-packages (from google-genai<2.0.0,>=1.64.0->google-adk>=1.5.0->flotorch[adk]) (1.9.0)
# Requirement already satisfied: sniffio in c:\git_files\resources\resources\venv\lib\site-packages (from google-genai<2.0.0,>=1.64.0->google-adk>=1.5.0->flotorch[adk]) (1.3.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\git_files\resources\resources\venv\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\git_files\resources\resources\venv\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\git_files\resources\resources\venv\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\git_files\resources\resources\venv\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]) (0.30.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\git_files\resources\resources\venv\lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk>=1.5.0->flotorch[adk]) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\git_files\resources\resources\venv\lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk>=1.5.0->flotorch[adk]) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\git_files\resources\resources\venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->google-adk>=1.5.0->flotorch[adk]) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\git_files\resources\resources\venv\lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk>=1.5.0->flotorch[adk]) (0.0.22)
# Requirement already satisfied: pywin32>=310 in c:\git_files\resources\resources\venv\lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk>=1.5.0->flotorch[adk]) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\git_files\resources\resources\venv\lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk>=1.5.0->flotorch[adk]) (3.3.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-api<1.39.0,>=1.36.0->google-adk>=1.5.0->flotorch[adk]) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]) (1.73.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]) (0.59b0)
# Requirement already satisfied: opentelemetry-util-http==0.59b0 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]) (1.17.3)
# Requirement already satisfied: six>=1.5 in c:\git_files\resources\resources\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk>=1.5.0->flotorch[adk]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\git_files\resources\resources\venv\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk>=1.5.0->flotorch[adk]) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\git_files\resources\resources\venv\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk>=1.5.0->flotorch[adk]) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\git_files\resources\resources\venv\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk>=1.5.0->flotorch[adk]) (3.3.2)
# Requirement already satisfied: alembic in c:\git_files\resources\resources\venv\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk>=1.5.0->flotorch[adk]) (1.18.4)
# Requirement already satisfied: tzdata in c:\git_files\resources\resources\venv\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk>=1.5.0->flotorch[adk]) (2025.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\git_files\resources\resources\venv\lib\site-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk>=1.5.0->flotorch[adk]) (2.0.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.9.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\git_files\resources\resources\venv\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (0.5.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\git_files\resources\resources\venv\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]) (3.3.2)
# Requirement already satisfied: zipp>=3.20 in c:\git_files\resources\resources\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<1.39.0,>=1.36.0->google-adk>=1.5.0->flotorch[adk]) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\git_files\resources\resources\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk>=1.5.0->flotorch[adk]) (0.6.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\git_files\resources\resources\venv\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\git_files\resources\resources\venv\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\git_files\resources\resources\venv\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\git_files\resources\resources\venv\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\git_files\resources\resources\venv\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\git_files\resources\resources\venv\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk>=1.5.0->flotorch[adk]) (1.23.0)
# Requirement already satisfied: Mako in c:\git_files\resources\resources\venv\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk>=1.5.0->flotorch[adk]) (1.3.10)
# Requirement already satisfied: pycparser in c:\git_files\resources\resources\venv\lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.6.6->google-adk>=1.5.0->flotorch[adk]) (3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\git_files\resources\resources\venv\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk>=1.5.0->flotorch[adk]) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ======================================================================
# 🧩 STEP 2 — Configuration
# ======================================================================
# Fill in your credentials directly below.
# This keeps the notebook self-contained and demo-ready.
# ======================================================================


FLOTORCH_API_KEY = "sk_"         # 🔑 your Flotorch API key
FLOTORCH_BASE_URL = "<gateway url>"   # 🌐 your Flotorch Gateway URL
AGENT_NAME = "<agent_name>"       # 🤖 Agent name configured in Console
APP_NAME = "email_ticket_router_demo"
USER_ID = "email_router_user_001"

# Gmail Credentials (create an App Password under Google Account -> Security -> App Passwords)
GMAIL_EMAIL = "<gmail>"
GMAIL_APP_PASSWORD = "<app password>"

# Team routing map (can customize for your org)
TEAMS = {
    "ui": {"lead_name": "<name>", "lead_email": "<gmail>"},
    "python_backend": {"lead_name": "<name>", "lead_email": "<gmail>"},
    "devops": {"lead_name": "<name>", "lead_email": "<gmail>"},
}

# Mail settings
IMAP_SERVER = "imap.gmail.com"
SMTP_SERVER = "smtp.gmail.com"
MAX_EMAILS_PER_RUN = 5
GMAIL_SUBJECT_KEYWORDS = ["bug", "issue", "feature", "task"]

print("✅ Configuration loaded successfully.")
# Out:
# ✅ Configuration loaded successfully.

# %%
# ======================================================================
# 📬 STEP 3 — Gmail Utilities
# ======================================================================
# Functions for connecting to Gmail (IMAP & SMTP),
# fetching unread emails, and sending replies.
# ======================================================================

import imaplib, smtplib, email, re
from email.header import decode_header, make_header
from email.mime.text import MIMEText
from email.utils import parseaddr
from typing import List, Tuple

# --- IMAP Connection ---
def connect_imap():
    m = imaplib.IMAP4_SSL(IMAP_SERVER)
    m.login(GMAIL_EMAIL, GMAIL_APP_PASSWORD)
    return m

# --- Fetch unread emails matching keywords ---
def search_unseen_matching_subject(m, keywords: List[str], max_count: int):
    m.select("INBOX")
    status, data = m.search(None, 'UNSEEN')
    if status != 'OK':
        return []
    ids = data[0].split()
    results = []
    for msg_id in reversed(ids):
        if len(results) >= max_count:
            break
        status, msg_data = m.fetch(msg_id, '(RFC822)')
        if status != 'OK':
            continue
        msg = email.message_from_bytes(msg_data[0][1])
        subj_raw = msg.get('Subject', '')
        try:
            subj = str(make_header(decode_header(subj_raw)))
        except Exception:
            subj = subj_raw
        if any(k.lower() in subj.lower() for k in keywords):
            results.append((msg_id, msg))
    return results

# --- Extract sender, subject, body ---
def extract_sender_subject_body(msg) -> Tuple[str, str, str]:
    sender = parseaddr(msg.get('From', ''))[1]
    subject = str(make_header(decode_header(msg.get('Subject', ''))))
    body = ""
    if msg.is_multipart():
        for part in msg.walk():
            if part.get_content_type() == 'text/plain' and 'attachment' not in str(part.get("Content-Disposition", "")):
                body = part.get_payload(decode=True).decode(part.get_content_charset() or 'utf-8', errors='ignore')
                break
    else:
        payload = msg.get_payload(decode=True)
        if payload:
            body = payload.decode(msg.get_content_charset() or 'utf-8', errors='ignore')
    body = re.sub(r"^>+.*$", "", body, flags=re.MULTILINE).strip()
    return sender, subject, body

# --- SMTP Send Helper ---
def send_smtp_text(to_addr: str, subject: str, body: str):
    msg = MIMEText(body, _charset='utf-8')
    msg['From'] = GMAIL_EMAIL
    msg['To'] = to_addr
    msg['Subject'] = subject
    with smtplib.SMTP_SSL(SMTP_SERVER, 465) as s:
        s.login(GMAIL_EMAIL, GMAIL_APP_PASSWORD)
        s.sendmail(GMAIL_EMAIL, [to_addr], msg.as_string())

print("📨 Gmail utilities ready.")
# Out:
# 📨 Gmail utilities ready.

# %%
# ======================================================================
# 🛠️ STEP 4 — Define Custom Tools
# ======================================================================
# These tools are the interface between the agent and real-world actions.
# The agent decides *when and how* to call them.
# ======================================================================

from google.adk.tools import FunctionTool
from typing import Dict, Optional

# --- Tool A: Fetch unread emails ---
def fetch_mail_tool(max_results: int = MAX_EMAILS_PER_RUN):
    m = connect_imap()
    matches = search_unseen_matching_subject(m, GMAIL_SUBJECT_KEYWORDS, max_results)
    emails = []
    for msg_id, msg in matches:
        sender, subject, body = extract_sender_subject_body(msg)
        emails.append({
            "id": msg_id.decode() if isinstance(msg_id, bytes) else str(msg_id),
            "sender": sender,
            "subject": subject,
            "body": body
        })
    m.logout()
    return emails

# --- Tool B: Route the task to the appropriate team lead ---
def route_task_tool(routing_team: str, title: str, summary: str, priority: str) -> Dict[str, str]:
    team_info = TEAMS.get(routing_team.lower())
    if not team_info:
        return {"status": f"error: unknown team '{routing_team}'"}
    subject = f"[{priority}] {title}"
    body = f"Hi {team_info['lead_name']},\n\nAssigned: {title}\nPriority: {priority}\n\nSummary:\n{summary}\n\n— Task Router"
    send_smtp_text(team_info["lead_email"], subject, body)
    return {"lead_name": team_info["lead_name"], "lead_email": team_info["lead_email"], "status": "sent"}

# --- Tool C: Send acknowledgment to sender ---
def send_ack_tool(sender_email: str, ack_body: str, ack_subject: Optional[str] = None) -> Dict[str, str]:
    subject = ack_subject or "Acknowledgment: we've received your request"
    send_smtp_text(sender_email, subject, ack_body)
    return {"to": sender_email, "status": "sent"}

# Wrap as ADK-compatible tools
custom_tools = [
    FunctionTool(func=fetch_mail_tool),
    FunctionTool(func=route_task_tool),
    FunctionTool(func=send_ack_tool),
]

print("🧰 Custom tools registered:", [t.func.__name__ for t in custom_tools])
# Out:
# 🧰 Custom tools registered: ['fetch_mail_tool', 'route_task_tool', 'send_ack_tool']

# %%
# ======================================================================
# ⚙️ STEP 5 — Initialize Flotorch Agent
# ======================================================================
# Connect to your configured agent in Flotorch Console.
# Make sure your Console agent has the correct system prompt and goal.
# ======================================================================

from google.adk.sessions import InMemorySessionService
from flotorch.adk.agent import FlotorchADKAgent
from google.adk import Runner
from google.genai import types

# Create session & agent client
session_service = InMemorySessionService()

flotorch_client = FlotorchADKAgent(
    agent_name=AGENT_NAME,
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_BASE_URL,
    custom_tools=custom_tools   # register your local action tools
)

agent = flotorch_client.get_agent()
runner = Runner(agent=agent, app_name=APP_NAME, session_service=session_service)
print("Connected to Flotorch Agent:", agent.name)
# Out:
# Connected to Flotorch Agent: strands

# %%
# ======================================================================
# ▶️ STEP 6 — Run Agent (check below cell for sample example of mail before tunning agent)
# ======================================================================
# This section creates a new session and executes the agent once.
# The agent will:
#   - Fetch unread emails
#   - Analyze & classify them
#   - Route tasks to leads
#   - Send acknowledgments
# ======================================================================

import asyncio

def run_agent_once(session_id: str):
    user_prompt = "Process unread mailbox: fetch and handle matching messages."
    content = types.Content(role="user", parts=[types.Part(text=user_prompt)])
    events = runner.run(user_id=USER_ID, session_id=session_id, new_message=content)

    final_outputs = []
    for event in events:
        if event.is_final_response() and event.content and event.content.parts:
            final_outputs.append(event.content.parts[0].text)
    return "\n".join(final_outputs) if final_outputs else "No output."

async def main_process():
    session = await session_service.create_session(app_name=APP_NAME, user_id=USER_ID)
    print(f"🆕 Session created: {session.id}")
    output = run_agent_once(session.id)
    print("\n--- 🧾 Agent Final Output ---\n", output)

await main_process()
# Out:
# 🆕 Session created: 0872cf1d-e17d-49e5-807a-aee8006e37e4
# Exception in thread Thread-74 (_asyncio_thread_main):
# Traceback (most recent call last):
#   File "C:\Users\FL_LPT-815\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\FL_LPT-815\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\runners.py", line 486, in _asyncio_thread_main
#     asyncio.run(_invoke_run_async())
#   File "C:\Users\FL_LPT-815\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\FL_LPT-815\AppData\Local\Programs\Python\Python311\Lib\asyncio\runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FL_LPT-815\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 654, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\runners.py", line 479, in _invoke_run_async
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\runners.py", line 632, in run_async
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\runners.py", line 617, in _run_with_trace
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\runners.py", line 853, in _exec_with_plugin
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\runners.py", line 606, in execute
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\agents\base_agent.py", line 297, in run_async
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\agents\llm_agent.py", line 479, in _run_async_impl
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py", line 754, in run_async
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py", line 841, in _run_one_step_async
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py", line 934, in _postprocess_async
#     async for event in agen:
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py", line 1052, in _postprocess_handle_function_calls_async
#     if function_response_event := await functions.handle_function_calls_async(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\functions.py", line 358, in handle_function_calls_async
#     return await handle_function_call_list_async(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\functions.py", line 404, in handle_function_call_list_async
#     function_response_events = await asyncio.gather(*tasks)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\functions.py", line 592, in _execute_single_function_call_async
#     function_response_event = await _run_with_trace()
#                               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\functions.py", line 539, in _run_with_trace
#     raise tool_error
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\functions.py", line 526, in _run_with_trace
#     function_response = await __call_tool_async(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\flows\llm_flows\functions.py", line 1111, in __call_tool_async
#     return await tool.run_async(args=args, tool_context=tool_context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\tools\function_tool.py", line 221, in run_async
#     return await self._invoke_callable(self.func, args_to_call)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Git_Files\resources\Resources\venv\Lib\site-packages\google\adk\tools\function_tool.py", line 238, in _invoke_callable
#     return target(**args_to_call)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FL_LPT-815\AppData\Local\Temp\ipykernel_26104\2906275205.py", line 13, in fetch_mail_tool
#   File "C:\Users\FL_LPT-815\AppData\Local\Temp\ipykernel_26104\1486600356.py", line 17, in connect_imap
#   File "C:\Users\FL_LPT-815\AppData\Local\Programs\Python\Python311\Lib\imaplib.py", line 612, in login
#     raise self.error(dat[-1])
# imaplib.IMAP4.error: b'[AUTHENTICATIONFAILED] Invalid credentials (Failure)'
# --- 🧾 Agent Final Output ---
#  No output.

# %%
# ======================================================================
# ▶️ Sample email examples for the agent to process
# ======================================================================
#sample1:Feature Request (UI)
'''
Subject: Feature: Add confirmation pop-up for experiment deletion

Body:
Hi Team,

When users delete an experiment there is no confirmation popup. Please implement a confirmation dialog on the UI to avoid accidental deletes.

Steps to reproduce:
1) Open experiment list.
2) Click delete on an experiment.
3) Observe deletion happens immediately.

Thanks,
QA
'''

#sample2:Bug Report (Backend)
'''
Subject: Bug: API returns 500 on /v1/experiments

Body:

Hi,

The experiments list API intermittently returns 500 errors. This started after the last deployment.

Error: InternalServerError stack trace...
Affects production for some users.

Please investigate urgently.
'''
# Out:
# '\nSubject: Bug: API returns 500 on /v1/experiments\n\nBody:\n\nHi,\n\nThe experiments list API intermittently returns 500 errors. This started after the last deployment.\n\nError: InternalServerError stack trace...\nAffects production for some users.\n\nPlease investigate urgently.\n'
