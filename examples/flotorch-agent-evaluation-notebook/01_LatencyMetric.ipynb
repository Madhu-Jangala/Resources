# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://drive.google.com/drive/folders/1IrwoNrb3AWLAhAqjlAkJNYa39p9eT9ui?usp=sharing)

# %% [markdown]
# # Flotorch Agent Latency Evaluation (Flotorch-Assistant Use Case)
#
# This notebook demonstrates how to measure and analyze the **agent latency** of a **Flotorch ADK agent** (configured as a **Flotorch-Assistant** that provides context-aware responses using Flotorch documentation via RAG) using the **Flotorch Eval** framework.
#
# The evaluation relies on **OpenTelemetry Traces** generated during the agent's run to provide a detailed breakdown of execution time across all steps (LLM calls, tool execution, etc.).
#
# ---
#
# ## Key Concepts
#
# * **Flotorch-Assistant**: An agent designed to provide context-aware responses using Flotorch documentation via RAG (Retrieval-Augmented Generation).
# * **OpenTelemetry Traces**: Detailed records of the agent's execution steps (spans) used to measure time taken by different operations.
# * **LatencyMetric**: A Flotorch Eval metric that extracts and summarizes latency information from the execution traces (agent trajectories). The evaluation metric used is **latency_summary**.
#
# ### Architecture Overview
#
# ![Workflow Diagram](diagrams/01_LatencyMetric_Workflow_Diagram.drawio.png)
# *Figure : Detailed workflow diagram showing the step-by-step process of latency evaluation from agent execution through trace collection to metric computation.*
#
# ---
#
# ## Requirements
#
# * Flotorch account with configured models and a knowledge base containing Flotorch documentation.
# * Valid Flotorch API key and gateway base URL.
# * Agent configured with OpenTelemetry tracing enabled.
#
# ---

# %% [markdown]
# ## Agent Setup in Flotorch Console
#
# **Important**: Before running this notebook, you need to create an agent in the Flotorch Console. This section provides step-by-step instructions on how to set up the agent.
#
# ### Step 1: Access Flotorch Console
#
# 1. **Log in to Flotorch Console**:
#    - Navigate to your Flotorch Console (e.g., `https://dev-console.flotorch.cloud`)
#    - Ensure you have the necessary permissions to create agents
#
# 2. **Navigate to Agents Section**:
#    - Click on **"Agents"** in the left sidebar
#    - You should see the "Agent Builder" option selected
#
# ### Step 2: Create New Agent
#
# 1. **Click "Create FloTorch Agent"**:
#    - Look for the blue **"+ Create FloTorch Agent"** button in the top right corner
#    - Click it to start creating a new agent
#
# 2. **Agent Configuration**:
#    - **Agent Name**: Choose a unique name for your agent (e.g., `flotorch-agent`)
#      - **Important**: The name should only contain alphanumeric characters and dashes (a-z, A-Z, 0-9, -)
#      - **Note**: Copy this agent name - you'll need to use it in the `agent_name` variable later
#    - **Description** (Optional): Add a description if desired
#
# ### Step 3: Configure Agent Details
#
# After creating the agent, you'll be directed to the agent configuration page. Configure the following:
#
# #### Required Configuration:
#
# 1. **Model** (`* Model`):
#    - **Required**: Select a model from the available options
#    - Example: `gpt-model` or any available model from your Flotorch gateway
#    - Click the edit icon to configure
#
# 2. **Agent Details** (`* Agent Details`):
#    - **Required**: Configure agent details
#    - **System Prompt**: Copy and paste the following system prompt:
#
# You are the Flotorch Support Agent. Your purpose is to assist users with questions about Flotorch by providing accurate, context-aware answers grounded strictly in official Flotorch documentation.
#
# Use the kb_tool to look up any information you are not fully certain about. Always query the knowledge base before answering if clarification, validation, or exact details are needed.
#
# Guidelines:
# Base every response on retrieved knowledge from kb_tool.
# If multiple document fragments are returned, synthesize them into a single clear answer.
# Never invent features, APIs, capabilities, or behaviors not found in the retrieved documentation.
# If the knowledge base lacks information, say so clearly and provide a safe, general-purpose suggestion.
# Provide concise, helpful explanations with step-by-step details when relevant.
# Maintain a professional, technical-support tone.
#
# Your outputs should always reflect the most accurate Flotorch information available via the kb_tool
#
#
#    - **Goal**: Copy and paste the following goal:
#
# To deliver precise, context-aware technical support for Flotorch by retrieving and grounding all answers in the Flotorch knowledge base using kb_tool, ensuring correctness, clarity, and factual alignment with documentation.
#
#
# #### Optional Configuration:
#
# 1. **Tools**:
#    - Tools will be added programmatically via the notebook (see Section 8)
#    - You can leave this as "Not Configured" in the console
#
# 2. **Input Schema**:
#    - Optional: Leave as "Not Configured" for this use case
#
# 3. **Output Schema**:
#    - Optional: Leave as "Not Configured" for this use case
#
# ### Step 4: Publish the Agent
#
# 1. **Review Configuration**:
#    - Ensure the Model and Agent Details are configured correctly
#    - Verify the System Prompt and Goal are set
#
# 2. **Publish Agent**:
#    - After configuration, click **"Publish"** or **"Make a revision"** to publish the agent
#    - Once published, the agent will have a version number (e.g., v1)
#
# 3. **Note the Agent Name**:
#    - **Important**: Copy the exact agent name you used when creating the agent
#    - You will need to replace `<your_agent_name>` in the `agent_name` variable in Section 2.1 (Global Provider Models and Agent Configuration)
#
# ### Step 5: Update Notebook Configuration
#
# 1. **Update Agent Name**:
#    - Navigate to Section 2.1 in this notebook
#    - Find the `agent_name` variable
#    - Replace `<your_agent_name>` with the exact agent name you created in the console
#
# **Example**:
# - If you created an agent named `flotorch-agent` in the console
# - Set `agent_name = "flotorch-agent"` in the notebook
#
# ### Summary of Required vs Optional Settings
#
# | Setting | Required/Optional | Value |
# |---------|------------------|-------|
# | **Agent Name** | **Required** | Choose a unique name (copy it for notebook) |
# | **Model** | **Required** | Select from available models |
# | **System Prompt** | **Required** | Use the system prompt provided above |
# | **Goal** | **Required** | Use the goal provided above |
# | **Tools** | **Optional** | Will be added via notebook code |
# | **Input Schema** | **Optional** | Can leave as "Not Configured" |
# | **Output Schema** | **Optional** | Can leave as "Not Configured" |
#
# **Note**: The tools (Knowledge Base, Web Search, Weather, News) will be added to the agent programmatically in the notebook code, so you don't need to configure them manually in the console.
#
# ---

# %% [markdown]
# ## 1. Setup and Installation
#
# ### Purpose
# Install the necessary packages for the Flotorch Evaluation framework required for agent latency evaluation.
#
# ### Key Components
# - **`flotorch-eval`**: Flotorch evaluation framework with all dependencies for latency metrics

# %%
# Install Flotorch Eval packages
# flotorch-eval: Flotorch evaluation framework with all dependencies

# %pip install flotorch-eval==2.0.0 flotorch[adk]==3.1.0b1
# Out:
# Collecting flotorch-eval==2.0.0
#   Using cached flotorch_eval-2.0.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: flotorch==3.1.0b1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch[adk]==3.1.0b1) (3.1.0b1)
# Requirement already satisfied: deepeval==3.6.9 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch-eval==2.0.0) (3.6.9)
# Requirement already satisfied: opentelemetry-api>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch-eval==2.0.0) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch-eval==2.0.0) (1.37.0)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch-eval==2.0.0) (2.12.4)
# Requirement already satisfied: ragas==0.3.8 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch-eval==2.0.0) (0.3.8)
# Requirement already satisfied: requests>=2.28.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch-eval==2.0.0) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from flotorch-eval==2.0.0) (4.15.0)
# Requirement already satisfied: httpx>=0.24 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch==3.1.0b1->flotorch[adk]==3.1.0b1) (0.28.1)
# Requirement already satisfied: google-adk>=1.5.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch[adk]==3.1.0b1) (1.20.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch[adk]==3.1.0b1) (1.2.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.34.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch[adk]==3.1.0b1) (1.37.0)
# Requirement already satisfied: opentelemetry-instrumentation-httpx>=0.48b0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from flotorch[adk]==3.1.0b1) (0.58b0)
# Requirement already satisfied: aiohttp in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (3.13.2)
# Requirement already satisfied: anthropic in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (0.75.0)
# Requirement already satisfied: click<8.3.0,>=8.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (8.2.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.9.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (1.53.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.67.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (1.76.0)
# Requirement already satisfied: jinja2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (3.1.6)
# Requirement already satisfied: nest_asyncio in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (1.6.0)
# Requirement already satisfied: ollama in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (0.6.1)
# Requirement already satisfied: openai in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (2.9.0)
# Requirement already satisfied: portalocker in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (3.2.0)
# Requirement already satisfied: posthog<7.0.0,>=6.3.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (6.9.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (2.12.0)
# Requirement already satisfied: pyfiglet in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (1.0.4)
# Requirement already satisfied: pytest in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (9.0.2)
# Requirement already satisfied: pytest-asyncio in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (1.3.0)
# Requirement already satisfied: pytest-repeat in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (0.9.4)
# Requirement already satisfied: pytest-rerunfailures<13.0,>=12.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (12.0)
# Requirement already satisfied: pytest-xdist in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (3.8.0)
# Requirement already satisfied: rich<15.0.0,>=13.6.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (14.2.0)
# Requirement already satisfied: sentry-sdk in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (2.47.0)
# Requirement already satisfied: setuptools in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (65.5.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (0.9.0)
# Requirement already satisfied: tenacity<=10.0.0,>=8.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (9.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (4.67.1)
# Requirement already satisfied: typer<1.0.0,>=0.9 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (0.20.0)
# Requirement already satisfied: wheel in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from deepeval==3.6.9->flotorch-eval==2.0.0) (0.45.1)
# Requirement already satisfied: numpy<3.0.0,>=1.21.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (2.3.5)
# Requirement already satisfied: datasets>=4.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (4.4.1)
# Requirement already satisfied: tiktoken in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (0.12.0)
# Requirement already satisfied: appdirs in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (1.4.4)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (5.6.3)
# Requirement already satisfied: instructor in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (1.13.0)
# Requirement already satisfied: gitpython in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (3.1.45)
# Requirement already satisfied: pillow>=10.4.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (12.0.0)
# Requirement already satisfied: networkx in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (3.6)
# Requirement already satisfied: scikit-network in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (0.33.5)
# Requirement already satisfied: langchain in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (1.1.0)
# Requirement already satisfied: langchain-core in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (1.1.0)
# Requirement already satisfied: langchain-community in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (0.4.1)
# Requirement already satisfied: langchain_openai in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from ragas==0.3.8->flotorch-eval==2.0.0) (1.1.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.21.0)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.6.5)
# Requirement already satisfied: fastapi<0.119.0,>=0.115.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.118.3)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.129.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.35.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.38.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.6.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.21)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.10.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.23.1)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.11.0a0)
# Requirement already satisfied: pyarrow>=14.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (22.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.9.0.post0)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.48.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (15.0.1)
# Requirement already satisfied: certifi in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.24->flotorch==3.1.0b1->flotorch[adk]==3.1.0b1) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.24->flotorch==3.1.0b1->flotorch[adk]==3.1.0b1) (1.0.9)
# Requirement already satisfied: idna in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.24->flotorch==3.1.0b1->flotorch[adk]==3.1.0b1) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.24->flotorch==3.1.0b1->flotorch[adk]==3.1.0b1) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.0.0->flotorch-eval==2.0.0) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]==3.1.0b1) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]==3.1.0b1) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]==3.1.0b1) (1.37.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-proto==1.37.0->opentelemetry-exporter-otlp-proto-grpc>=1.34.0->flotorch[adk]==3.1.0b1) (6.33.2)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]==3.1.0b1) (0.58b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]==3.1.0b1) (0.58b0)
# Requirement already satisfied: opentelemetry-util-http==0.58b0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]==3.1.0b1) (0.58b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]==3.1.0b1) (1.17.3)
# Requirement already satisfied: packaging>=18.0 in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-httpx>=0.48b0->flotorch[adk]==3.1.0b1) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.0.0->flotorch-eval==2.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.0.0->flotorch-eval==2.0.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.0.0->flotorch-eval==2.0.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.28.0->flotorch-eval==2.0.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.28.0->flotorch-eval==2.0.0) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.3.1)
# Requirement already satisfied: cryptography in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from authlib<2.0.0,>=1.5.1->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (46.0.3)
# Requirement already satisfied: colorama in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from click<8.3.0,>=8.0.0->deepeval==3.6.9->flotorch-eval==2.0.0) (0.4.6)
# Requirement already satisfied: filelock in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (3.20.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (0.4.0)
# Requirement already satisfied: pandas in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (2.3.3)
# Requirement already satisfied: xxhash in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (1.2.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.26.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.8.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.7.1)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.5.4)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.15.4)
# Requirement already satisfied: zipp>=3.20 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.0.0->flotorch-eval==2.0.0) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.30.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.4.3)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.10.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from mcp<2.0.0,>=1.10.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.0.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from openai->deepeval==3.6.9->flotorch-eval==2.0.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from openai->deepeval==3.6.9->flotorch-eval==2.0.0) (0.11.1)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.28.0)
# Requirement already satisfied: six>=1.5 in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from posthog<7.0.0,>=6.3.0->deepeval==3.6.9->flotorch-eval==2.0.0) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from posthog<7.0.0,>=6.3.0->deepeval==3.6.9->flotorch-eval==2.0.0) (2.2.1)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pytest->deepeval==3.6.9->flotorch-eval==2.0.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pytest->deepeval==3.6.9->flotorch-eval==2.0.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from pytest->deepeval==3.6.9->flotorch-eval==2.0.0) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from rich<15.0.0,>=13.6.0->deepeval==3.6.9->flotorch-eval==2.0.0) (4.0.0)
# Requirement already satisfied: greenlet>=1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.2.4)
# Requirement already satisfied: alembic in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.17.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.9->deepeval==3.6.9->flotorch-eval==2.0.0) (1.5.4)
# Requirement already satisfied: tzdata in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->deepeval==3.6.9->flotorch-eval==2.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->deepeval==3.6.9->flotorch-eval==2.0.0) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->deepeval==3.6.9->flotorch-eval==2.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->deepeval==3.6.9->flotorch-eval==2.0.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->deepeval==3.6.9->flotorch-eval==2.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from aiohttp->deepeval==3.6.9->flotorch-eval==2.0.0) (1.22.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from gitpython->ragas==0.3.8->flotorch-eval==2.0.0) (4.0.12)
# Requirement already satisfied: pre-commit>=4.3.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from instructor->ragas==0.3.8->flotorch-eval==2.0.0) (4.5.0)
# Requirement already satisfied: ty>=0.0.1a23 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from instructor->ragas==0.3.8->flotorch-eval==2.0.0) (0.0.1a32)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from jinja2->deepeval==3.6.9->flotorch-eval==2.0.0) (3.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langchain->ragas==0.3.8->flotorch-eval==2.0.0) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langchain-core->ragas==0.3.8->flotorch-eval==2.0.0) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langchain-core->ragas==0.3.8->flotorch-eval==2.0.0) (0.4.48)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langchain-community->ragas==0.3.8->flotorch-eval==2.0.0) (1.0.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langchain-community->ragas==0.3.8->flotorch-eval==2.0.0) (0.6.7)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from tiktoken->ragas==0.3.8->flotorch-eval==2.0.0) (2025.11.3)
# Requirement already satisfied: execnet>=2.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pytest-xdist->deepeval==3.6.9->flotorch-eval==2.0.0) (2.1.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from scikit-network->ragas==0.3.8->flotorch-eval==2.0.0) (1.16.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas==0.3.8->flotorch-eval==2.0.0) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas==0.3.8->flotorch-eval==2.0.0) (0.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->ragas==0.3.8->flotorch-eval==2.0.0) (5.0.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.4.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (3.2.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (1.2.0)
# Requirement already satisfied: typer-slim in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (0.20.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->ragas==0.3.8->flotorch-eval==2.0.0) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community->ragas==0.3.8->flotorch-eval==2.0.0) (1.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->ragas==0.3.8->flotorch-eval==2.0.0) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->ragas==0.3.8->flotorch-eval==2.0.0) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain->ragas==0.3.8->flotorch-eval==2.0.0) (0.2.10)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas==0.3.8->flotorch-eval==2.0.0) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas==0.3.8->flotorch-eval==2.0.0) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->ragas==0.3.8->flotorch-eval==2.0.0) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.6.0->deepeval==3.6.9->flotorch-eval==2.0.0) (0.1.2)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas==0.3.8->flotorch-eval==2.0.0) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas==0.3.8->flotorch-eval==2.0.0) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas==0.3.8->flotorch-eval==2.0.0) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pre-commit>=4.3.0->instructor->ragas==0.3.8->flotorch-eval==2.0.0) (20.35.4)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.0.0)
# Requirement already satisfied: Mako in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (1.3.10)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets>=4.0.0->ragas==0.3.8->flotorch-eval==2.0.0) (2025.2)
# Requirement already satisfied: pycparser in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (2.23)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->ragas==0.3.8->flotorch-eval==2.0.0) (1.12.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk>=1.5.0->flotorch[adk]==3.1.0b1) (0.6.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->ragas==0.3.8->flotorch-eval==2.0.0) (1.1.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\fl_lpt-815\appdata\local\programs\python\python311\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas==0.3.8->flotorch-eval==2.0.0) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\fl_lpt-815\appdata\roaming\python\python311\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor->ragas==0.3.8->flotorch-eval==2.0.0) (4.5.0)
# Using cached flotorch_eval-2.0.0-py3-none-any.whl (64 kB)
# Installing collected packages: flotorch-eval
#   Attempting uninstall: flotorch-eval
#     Found existing installation: flotorch-eval 2.0.0b1
#     Uninstalling flotorch-eval-2.0.0b1:
#       Successfully uninstalled flotorch-eval-2.0.0b1
# Successfully installed flotorch-eval-2.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2.Authentication and Credentials
#
# ### Purpose
# Configure your Flotorch API credentials and gateway URL for authentication.
#
# ### Key Components
# This cell configures the essential authentication and connection parameters:
#
# **Authentication Parameters**:
#
# | Parameter | Description | Example |
# |-----------|-------------|---------|
# | `FLOTORCH_API_KEY` | Your API authentication key (found in your Flotorch Console). Securely entered using `getpass` to avoid displaying in the notebook | `sk_...` |
# | `FLOTORCH_BASE_URL` | Your Flotorch gateway endpoint URL | `https://dev-console.flotorch.cloud` |
#
# **Note**: Use secure credential management in production environments.

# %%
import getpass  # Securely prompt without echoing in notebooks

# authentication for Flotorch access
try:
    FLOTORCH_API_KEY = getpass.getpass("Paste your API key here: ")  
    print(f"✓ FLOTORCH_API_KEY set successfully")
except getpass.GetPassWarning as e:
    print(f"Warning: {e}")
    FLOTORCH_API_KEY = ""
    print(f"✗ FLOTORCH_API_KEY not set")

FLOTORCH_BASE_URL = input("Paste your Flotorch Base URL here: ")   # https://dev-gateway.flotorch.cloud
print(f"✓ FLOTORCH_BASE_URL set: {FLOTORCH_BASE_URL}")

print("✓ All credentials configured successfully!")

# %% [markdown]
# ### 2.1. Global Provider Models and Agent Configuration
#
# ### Purpose
# Define available models from the Flotorch gateway and configure agent-specific parameters.
#
# ### Key Components
#
# **Global Provider Models**: These are the available models from the Flotorch gateway that can be used for evaluation and agent operations:
#
# | Model Variable | Model Name | Description |
# |----------------|------------|-------------|
# | `MODEL_CLAUDE_HAIKU` | `flotorch/flotorch-claude-haiku-4-5` | Claude Haiku model via Flotorch gateway |
# | `MODEL_CLAUDE_SONNET` | `flotorch/flotorch-claude-sonnet-3-5-v2` | Claude Sonnet model via Flotorch gateway |
# | `MODEL_AWS_NOVA_PRO` | `flotorch/flotorch-aws-nova-pro` | AWS Nova Pro model via Flotorch gateway |
# | `MODEL_AWS_NOVA_LITE` | `flotorch/flotorch-aws-nova-lite` | AWS Nova Lite model via Flotorch gateway |
# | `MODEL_AWS_NOVA_MICRO` | `flotorch/flotorch-aws-nova-micro` | AWS Nova Micro model via Flotorch gateway |
#
# **Agent Configuration Parameters**:
#
# | Parameter | Description | Example |
# |-----------|-------------|---------|
# | `KNOWLEDGE_BASE` | The ID of your Flotorch Knowledge Base | `knowledge-base` |
# | `agent_name` | The name of your Flotorch ADK agent | `flotorch-agent` |
# | `default_evaluator` | The LLM model used for evaluation (can use MODEL_* variables above) | `MODEL_CLAUDE_SONNET` or `flotorch/flotorch-model` |
# | `app_name` | The application name identifier | `agent-evaluation-app-name_01` |
# | `user_id` | The user identifier | `agent-evaliation-user-01` |

# %%
# ============================================================================
# Global Provider Models (Flotorch Gateway Models)
# ============================================================================
# These models are available from the Flotorch gateway and can be used
# for evaluation, agent operations, and other tasks.

MODEL_CLAUDE_HAIKU = "flotorch/flotorch-claude-haiku-4-5"
MODEL_CLAUDE_SONNET = "flotorch/flotorch-claude-sonnet-3-5-v2"
MODEL_AWS_NOVA_PRO = "flotorch/flotorch-aws-nova-pro"
MODEL_AWS_NOVA_LITE = "flotorch/flotorch-aws-nova-lite"
MODEL_AWS_NOVA_MICRO = "flotorch/flotorch-aws-nova-micro"

print("✓ Global provider models defined")

KNOWLEDGE_BASE = "<your_knowledge_base_id>"  # The ID of your Flotorch Knowledge Base                          || ex : knowledge-base
agent_name = "<your_agent_name>"  # The name of your Flotorch ADK agent                                        || ex : flotorch-agent
default_evaluator = MODEL_CLAUDE_HAIKU  # The LLM model used for evaluation. Can be modified to use any MODEL_* constant above (e.g., MODEL_CLAUDE_SONNET, MODEL_AWS_NOVA_PRO)
app_name = "<your_app_name>"  # The application name identifier                                                || ex : agent-evaluation-app-name_01
user_id = "<your_user_id>"  # The user identifier                                                              || ex : agent-evaliation-user-01

print("✓ Agent Configuration Parameter defined ")
# Out:
# ✓ Global provider models defined
# ✓ Agent Configuration Parameter defined

# %%
FLOTORCH_API_KEY="sk_sAlzWZrMM5JJUj0Fgmkpc5A4HFZyXzU2LDVa3L6W9VQ=_MTAwNjNjNDQtYjk3YS00NjdhLWFkYTgtZWJkYzU0OTFlNjY5_OTFiYWY4ZDQtNWFjNy00YWJmLWI3OGYtODMxZWFlOWY1ZWY5"
FLOTORCH_BASE_URL="https://dev-gateway.flotorch.cloud"
KNOWLEDGE_BASE="knowledge-base"
agent_name="flotorch-agent"

# %% [markdown]
# ## 3. Import Required Libraries
#
# ### Purpose
# Import all required components for evaluating the Flotorch Support Agent latency using Flotorch Eval.
#
# ### Key Components
# - **`AgentEvaluator`**: Core client for agent evaluation orchestration and trace fetching
# - **`LatencyMetric`**: Flotorch Eval metric that extracts and summarizes latency information from execution traces
# - **`FlotorchADKAgent`**: Creates and configures Flotorch ADK agents with custom tools and tracing
# - **`FlotorchADKSession`**: Manages agent sessions for multi-turn conversations
# - **`FlotorchVectorStore`**: Connects to the Flotorch knowledge base for RAG-based context retrieval
# - **`extract_vectorstore_texts`**: Utility helper for extracting text from vector-store search results
# - **`Runner`**: Executes agent queries and coordinates the agent execution flow
# - **`FunctionTool`**: Wraps Python functions as tools that can be used by the agent
# - **`types`**: Google ADK types for creating message content and handling agent events
# - **`pandas`**: Data manipulation and display for formatted results tables
# - **`display`**: IPython display utility for rendering formatted outputs

# %%
# Required imports
# Flotorch Eval components
from flotorch_eval.agent_eval.core.client import AgentEvaluator
from flotorch_eval.agent_eval.metrics.latency_metrics import LatencyMetric

# Flotorch ADK components
from flotorch.adk.agent import FlotorchADKAgent
from flotorch.adk.sessions import FlotorchADKSession
from flotorch.sdk.memory import FlotorchVectorStore
from flotorch.sdk.utils.memory_utils import extract_vectorstore_texts

# Google ADK components
from google.adk.runners import Runner
from google.adk.tools import FunctionTool
from google.genai import types

# Utilities
import pandas as pd
from flotorch_eval import display_agent_evaluation_results

print("✓ Imported necessary libraries successfully")
# Out:
# ✓ Imported necessary libraries successfully

# %% [markdown]
# ## 4. Flotorch Support Agent Setup
#
# ### Purpose
# Set up the Flotorch Support Agent with OpenTelemetry tracing enabled to capture detailed execution data for latency evaluation.
#
# ### Key Components
# 1. **FlotorchADKAgent** (`agent_client`):
#    - Initializes the agent for providing context-aware responses using Flotorch documentation via RAG
#    - Configures `tracer_config` with `enabled: True` and `sampling_rate: 1` to capture 100% of traces
#    - Essential for evaluation as traces contain complete latency information
# 2. **FlotorchADKSession** (`session_service`): Manages agent sessions for multi-turn conversations
# 3. **Runner** (`runner`): Executes agent queries and coordinates the agent execution flow
#
# These components work together to run the Flotorch Support Agent and generate OpenTelemetry traces for latency analysis.
#
# ### Custom Tool: RAG-based Knowledge Base Search
#
# The Flotorch Support Agent uses a custom tool (`kb_tool`) that integrates with the Flotorch knowledge base to retrieve relevant documentation context. This tool:
# - Accepts a query string as input
# - Performs semantic search in the vectorstore using FlotorchVectorStore
# - Extracts and returns relevant text chunks from Flotorch documentation
# - Handles errors gracefully with structured error responses
#
# The tool is wrapped as a `FunctionTool` that can be used by the agent to provide context-aware responses using Flotorch documentation via RAG.

# %% [markdown]
# ### Knowledge Base Setup
#
# **Important**: Before running the code below, you need to create a Knowledge Base in the Flotorch Console.
#
# **For detailed step-by-step instructions on how to create a Knowledge Base in the Flotorch Console**, refer to the `agents/flotorch_assistant_kb/flotorch_console.md` file, which provides clear instructions on:
# - Navigating to the Knowledge Bases section
# - Creating a new knowledge base
# - Uploading documentation files
# - Configuring embedding settings
# - Copying the Knowledge Base ID
#
# After creating the knowledge base, copy the Knowledge Base ID/name and update the `KNOWLEDGE_BASE` variable in Section 2.1.
#
# **For more information about knowledge base and RAG**, you can also refer to:
# - `agents/flotorch_assistant_kb/flotorch_rag_memory.md`: Detailed information about RAG and memory in Flotorch
# - `agents/flotorch_assistant_kb/flotorch_agents.md`: Information about creating and configuring Flotorch agents
#
# The code below initializes the connection to your knowledge base and creates the `kb_tool` function that the agent will use to search the Flotorch documentation via RAG (Retrieval-Augmented Generation).

# %%
# Initialize the Flotorch Vector Store (Knowledge Base)
kb = FlotorchVectorStore(
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_BASE_URL,
    vectorstore_id=KNOWLEDGE_BASE
)

def kb_tool(query: str) -> dict:
    """
    Custom tool for searching the Flotorch knowledge base.
    Performs semantic search and returns relevant text chunks.
    """
    try:
        if not query:
            return {
                "success": False,
                "results": [],
                "error": "Empty query provided."
            }

        # Perform semantic search in vectorstore
        context = kb.search(query)
        results = extract_vectorstore_texts(context)

        return {
            "success": True,
            "results": results,
            "error": None
        }

    except Exception as e:
        return {
            "success": False,
            "results": [],
            "error": str(e)
        }


# Register the custom tool
tools = [FunctionTool(kb_tool)]

print("✓ Knowledge base tool setup completed!")
# Out:
# ✓ Knowledge base tool setup completed!

# %% [markdown]
# ## 5. Agent and Runner Initialization
#
# ### Purpose
# Set up the Flotorch ADK Agent and Runner with OpenTelemetry tracing enabled to capture detailed latency data for evaluation.
#
# ### Key Components
# 1. **FlotorchADKAgent** (`agent_client`):
#    - Initializes the agent with custom RAG tools
#    - Configures `tracer_config` with `enabled: True` and `sampling_rate: 1` to capture 100% of traces
#    - Essential for latency measurement as traces contain timing information
# 2. **FlotorchADKSession** (`session_service`): Manages agent sessions for multi-turn conversations
# 3. **Runner** (`runner`): Executes agent queries and coordinates the agent execution flow
#
# These components work together to run the Flotorch Support Agent and generate OpenTelemetry traces for latency analysis.

# %%
# Initialize Flotorch ADK Agent with tracing enabled
agent_client = FlotorchADKAgent(
    agent_name=agent_name,
    custom_tools=tools,
    base_url=FLOTORCH_BASE_URL,
    api_key=FLOTORCH_API_KEY,
    tracer_config={
        "enabled": True,                                                   # Enable tracing for latency measurement
        "endpoint": "https://dev-observability.flotorch.cloud/v1/traces",  # Dev observability OTLP HTTP endpoint (used by QA)
        "sampling_rate": 1                                                 # Sample 100% of traces
    }
)
agent = agent_client.get_agent()

# Initialize session service
session_service = FlotorchADKSession(
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_BASE_URL,
)

# Create the ADK Runner to execute agent queries
runner = Runner(
    agent=agent,
    app_name=app_name,
    session_service=session_service
)

print("✓ Agent and runner and session setup completed!")
# Out:
# ✓ Agent and runner and session setup completed!

# %% [markdown]
# ## 6. Helper Function for Running a Query
#
# ### Purpose
# Define a helper function that executes a single-turn query with the agent and extracts the final response. The agent execution is automatically traced for latency measurement.
#
# ### Functionality
# The `run_single_turn` function:
# - Accepts a `Runner`, query string, session ID, and user ID as parameters
# - Creates a user message using Google ADK types
# - Executes the query through the runner
# - Iterates through events to find and return the final agent response
# - Returns a fallback message if no response is found
#
# This function simplifies the process of running queries and ensures trace generation during execution.

# %%
def run_single_turn(runner: Runner, query: str, session_id: str, user_id: str) -> str:
    """
    Execute a single-turn query with the agent and return the final response.
    The agent execution is traced automatically.
    """
    content = types.Content(role="user", parts=[types.Part(text=query)])
    events = runner.run(user_id=user_id, session_id=session_id, new_message=content)

    # Extract the final response
    for event in events:
        if event.is_final_response() and event.content and event.content.parts:
            return event.content.parts[0].text
    return "No response from agent."

print("✓ Helper function 'run_single_turn' defined successfully")
# Out:
# ✓ Helper function 'run_single_turn' defined successfully

# %% [markdown]
# ## 7. Define Query
#
# ### Purpose
# Define the sample query that will be executed by the Flotorch Support Agent to generate OpenTelemetry traces for latency evaluation.
#
# ### Key Components
# - **`query`**: A sample question that will be processed by the agent
#   - This query will trigger the agent to use RAG (knowledge base search) and generate a response
#   - The execution will be automatically traced to capture latency information
#   - Example: "How to create agents in flotorch console?"
#
# The query can be modified to test different scenarios and measure latency for various types of questions.

# %%
# Execute the query to generate traces

query = "How to create agents in flotorch console?"

print(f"✓ Query defined: {query}")
# Out:
# ✓ Query defined: How to create agents in flotorch console?

# %% [markdown]
# ## 8. Run the Query and Get Trace ID
#
# ### Purpose
# Execute a sample query with the Flotorch Support Agent to generate OpenTelemetry traces that contain latency data for evaluation.
#
# ### Process
# 1. **Create Session**: Initialize a new session for the agent interaction
# 2. **Execute Query**: Run a sample query ("How to create agents in flotorch console?") through the agent
# 3. **Retrieve Trace IDs**: Extract the generated trace IDs from the agent client
# 4. **Display Results**: Print the agent response and trace ID for verification
#
# The execution automatically generates OpenTelemetry traces that record timing information for all agent operations (LLM calls, tool executions, etc.), which will be used for latency evaluation.

# %%
# Create a new session
session = await runner.session_service.create_session(
    app_name=app_name,
    user_id=user_id,
)
print(f"Session created: {session.id}")

response = run_single_turn(
    runner=runner,
    query=query,
    session_id=session.id,
    user_id=user_id
)

# Retrieve the generated trace IDs
trace_ids = agent_client.get_tracer_ids()
print("Agent Response:")
print(response[:200] + "..." if len(response) > 200 else response)
print(f"Found {len(trace_ids)} trace(s). First trace ID: {trace_ids[0] if trace_ids else 'N/A'}")

print(f"✓ Trace IDs retrieved: {len(trace_ids)} trace(s) generated")
# Out:
# Session created: 3cc61e5b-03f2-4819-a4cd-e0d9b0acfa21
# Agent Response:
# To create an agent in the Flotorch Console, follow these steps:
#
# 1. **Access the Flotorch Console**: Log in to your Flotorch account and navigate to the console.
#
# 2. **Initiate Agent Creation**: Click...
# Found 1 trace(s). First trace ID: 9f80ce3b15c2d3658e99d7bc628bb59e
# ✓ Trace IDs retrieved: 1 trace(s) generated

# %% [markdown]
# ## 9. Latency Evaluation with Flotorch Eval
#
# ### Purpose
# Initialize the `AgentEvaluator`, fetch the OpenTelemetry trace, and run the `LatencyMetric` to compute the performance breakdown. The evaluation metric **latency_summary** provides detailed latency statistics for the Flotorch Support Agent.
#
# ### Key Components
# 1. **LatencyMetric**: Initializes the latency metric that will analyze trace data
# 2. **AgentEvaluator** (`client`):
#    - Connects to the Flotorch gateway using API credentials
#    - Configured with a default evaluator model
#    - Provides methods to fetch and evaluate traces
# 3. **Trace Fetching**: Retrieves the complete trace data using the trace ID generated during agent execution
#
# The fetched trace contains detailed timing information for all agent operations, which will be analyzed by the LatencyMetric to compute the latency_summary.

# %%
# Initialize the LatencyMetric
metrics = [LatencyMetric()]

# Initialize the AgentEvaluator client
client = AgentEvaluator(
    api_key=FLOTORCH_API_KEY,
    base_url=FLOTORCH_BASE_URL,
    default_evaluator=default_evaluator
)
print("✓ AgentEvaluator client initialized successfully")

traces = None
if trace_ids:
    # Fetch the trace data from the Flotorch gateway
    traces = client.fetch_traces(trace_ids[0])
else:
    print("✗ No trace IDs found to fetch.")
# Out:
# ✓ AgentEvaluator client initialized successfully

# %% [markdown]
# ## 10. Run Evaluation
#
# ### Purpose
# Execute the latency evaluation by processing the fetched OpenTelemetry trace using the LatencyMetric to compute performance breakdown.
#
# ### Process
# - Calls `client.evaluate()` with the trace data and LatencyMetric
# - The evaluator processes the trace to extract timing information for all agent steps
# - Computes the **latency_summary** metric which includes:
#   - Total latency for root steps
#   - Average step latency
#   - Detailed breakdown by operation type (LLM calls, tool execution, etc.)
# - Returns evaluation results with trajectory ID and metric scores
#
# This step generates the latency analysis that will be displayed in the next section.

# %%
if 'traces' in locals() and traces:
    # Evaluate the trace using the LatencyMetric
    results = await client.evaluate(
        trace=traces,
        metrics=metrics
    )

    print("✓ Evaluation completed successfully!")
else:
    print("Cannot evaluate: No traces were available.")
# Out:
# ✓ Evaluation completed successfully!

# %% [markdown]
# ## 11. Display and Interpret Results
#
# ### Purpose
# Display the evaluation results using the built-in `display_agent_evaluation_results` function from `flotorch_eval`, which provides a clean, formatted view of the latency_summary metric results.
#
# ### Functionality
# The `display_agent_evaluation_results` function (imported from `flotorch_eval`):
# - Automatically extracts and formats all evaluation metrics from the results
# - Displays the `latency_summary` metric with a structured breakdown showing:
#   - Total Latency (Root Steps)
#   - Average Root Step Latency
#   - Detailed latency breakdown for each operation (with hierarchical nesting)
# - Uses styled HTML formatting for clean presentation in notebooks
# - Handles multiple metrics and displays them in a user-friendly table format
#
# You can directly call `display_agent_evaluation_results(results)` with the evaluation results to visualize the latency performance metrics.

# %%
if 'results' in locals():
    display_agent_evaluation_results(results)
else:
    print("No results object found. Please run sections 9 and 10 first.")
# Out:
# <style type="text/css">
# #T_598ea th {
#   text-align: left;
# }
# #T_598ea_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_598ea">
#   <thead>
#     <tr>
#       <th id="T_598ea_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_598ea_level0_col1" class="col_heading level0 col1" >Score</th>
#       <th id="T_598ea_level0_col2" class="col_heading level0 col2" >Details</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_598ea_row0_col0" class="data row0 col0" >latency_summary</td>
#       <td id="T_598ea_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_598ea_row0_col2" class="data row0 col2" >Total Latency (Root Steps): 158045.78 ms
# Average Root Step Latency: 2195.08 ms
# Latency Breakdown:
# &nbsp;&nbsp;&nbsp;&nbsp;- invocation: 36451.97 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- GET: 567.19 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- GET: 637.94 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 1174.78 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- invoke_agent flotorch_agent: 32896.0 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- GET: 1332.92 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 3465.96 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- call_llm: 3078.93 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 836.43 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 1848.83 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- Chat Completions: 0.82 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- Chat Completions: 1279.28 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- gateway.route_chat: 1276.46 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.preprocessing: 2.59 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.process_message_0: 1.06 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.partial_replacement_0: 0.43 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- parse_request: 0.15 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.process_message_1: 1.25 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.partial_replacement_1: 0.54 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- model.flotorch_request: 1272.96 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- model.lookup: 0.35 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- guardrails.input: 0.21 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- routing.strategy_execution: 1269.97 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- cache.lookup: 0.06 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.handle_chat_request: 1267.86 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.chat_request: 1268.32 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.parameter_processing: 0.79 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.factory_creation: 0.2 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.api_call: 1265.77 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- cache.store: 0.2 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- guardrails.output: 0.2 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- cost.calculation: 0.17 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- GET: 2660.08 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 2700.65 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 1878.83 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- Vector Stores: 790.38 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- parse_request: 0.63 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- gateway.route_vector_search: 658.17 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- execute_tool kb_tool: 1.11 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- GET: 1417.6 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 1483.92 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- call_llm: 8616.94 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 2294.84 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 5932.73 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- Chat Completions: 0.81 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- Chat Completions: 5110.09 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- gateway.route_chat: 5105.98 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- parse_request: 0.2 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.process_message_2: 1.56 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.process_message_0: 2.47 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.partial_replacement_2: 0.43 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.process_message_1: 2.68 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.process_message_3: 1.83 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.preprocessing: 3.68 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.partial_replacement_1: 1.14 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.partial_replacement_0: 1.04 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- prompt.partial_replacement_3: 0.61 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- model.flotorch_request: 5101.39 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- guardrails.input: 0.34 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- model.lookup: 0.42 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- routing.strategy_execution: 5097.51 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- cache.lookup: 0.07 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.parameter_processing: 0.2 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.handle_chat_request: 5095.24 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.chat_request: 5095.71 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.factory_creation: 0.23 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- provider.api_call: 5092.21 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- cache.store: 0.23 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- cost.calculation: 0.17 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- guardrails.output: 0.19 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- GET: 535.4 ms
# &nbsp;&nbsp;&nbsp;&nbsp;- POST: 2157.48 ms</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 12. Interpreting the Latency Breakdown
#
# The **latency_summary** metric is a vital tool for performance monitoring of the Flotorch Support Agent:
#
# * **Total Latency (Root Steps)**: The cumulative execution time for all root-level operations in milliseconds. This represents the end-to-end time from query initiation to final response.
# * **Average Root Step Latency**: The mean execution time across all root steps, providing a baseline for expected performance.
# * **Latency Breakdown**: Detailed timing information for individual operations:
#     * **invocation**: Total time for the agent invocation cycle
#     * **invoke_agent**: Time spent in the agent execution framework
#     * **call_llm**: Time taken for LLM API calls (can include multiple calls in a single turn)
#     * **execute_tool**: Time spent executing custom tools (e.g., RAG knowledge base search)
#     * Other operation-specific latencies as captured in the trace
#
# For a Flotorch Support Agent, understanding latency breakdown helps identify:
# - **LLM call bottlenecks**: If `call_llm` latencies are high, consider model optimization or caching strategies
# - **RAG search performance**: If `execute_tool` (knowledge base search) is slow, optimize vector store queries or indexing
# - **Overall response time**: Monitor total latency to ensure the agent delivers fast, context-aware responses using Flotorch documentation

# %% [markdown]
# ## 13. Summary of Agent Latency Evaluation Notebook
#
# This notebook demonstrates the professional methodology for evaluating the latency performance of a **Flotorch ADK Agent** (configured as a **Flotorch-Assistant use case** that provides context-aware responses using Flotorch documentation via RAG) using the **Flotorch Eval framework**.
#
# **Use Case**: Flotorch-Assistant  - Provides context-aware responses using Flotorch documentation via RAG.
#
# **Evaluation Metric**: latency_summary
#
# ## Core Process
#
# ### 1. Setup and Instrumentation
# - Configure a `FlotorchADKAgent` with custom RAG tools (e.g., a knowledge base search function for Flotorch documentation).
# - Enable **OpenTelemetry Tracing** via the `tracer_config`.
# - This instrumentation allows detailed capture of timing and internal operations.
#
# ### 2. Execution and Data Generation
# - Run a sample query through the agent using the **Runner**.
# - This automatically generates an **Agent Trajectory** in the form of OpenTelemetry traces.
# - The trace records the timing of each component, including:
#   - LLM calls
#   - RAG tool executions (knowledge base search)
#   - Step-by-step agent operations
#
# ### 3. Evaluation
# - Use the `AgentEvaluator` client along with the specialized **LatencyMetric** from `flotorch-eval`.
# - The evaluator processes the trace data to compute latency statistics using the **latency_summary** metric.
#
# ### 4. Analysis
# - The notebook displays a thorough latency breakdown, including:
#   - **Total Latency (Root Steps)**
#   - **Average Root Step Latency**
#   - Timing for individual steps such as:
#     - `invocation`
#     - `call_llm`
#     - `execute_tool` (RAG search operations)
#
# ## Purpose and Benefits
#
# This evaluation provides **actionable performance metrics** that help developers:
#
# - Identify latency bottlenecks in the Flotorch Support Agent
# - Optimize slow operations, particularly RAG search performance
# - Track performance trends over time
# - Ensure the Flotorch Support Agent delivers **fast and reliable context-aware responses** using Flotorch documentation
